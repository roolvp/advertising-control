# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Practical Budget Pacing Algorithms, PID Controler and Simulation Test Bed for eBay Marketplace Sponsored Search
#
# Recreation of the simulations and techniques used by Ebay in this paper http://papers.adkdd.org/2023/papers/adkdd23-nguyen-practical.pdf
#
#
# This notebook adds:
# - Adds a new PID control method and compares with the pacing algorithms used in the paper
# - Simulates user-interaction data, as we don't have access to it.

# %%
import pandas as pd

# %%
# Simulate 1440 minutes in a day
# Simulate bids for competing campaigns (3 campaigns with different budgets)
# Calculate Metrics for each campaign
# Use different pacing algorithms to spend budget
# Add PID to each campaign
# Build a nice UI


# Create dataframe that has
# Keyword, Item, Time, pCTR(probability of click through rate), bid

# %%
# Simulate 1440 minutes in a day, M campaigns competing for N keywords, pCTR, bid

# Define data
data = {
    # Each item is a book that represents a campaign
    'Item': ['Time Series Analysis: Forecasting and Control', 'Practical Statistics for Data Scientists', 'Designing Data-Intensive Applications'],
    # They are all bidding on the same keyword
    'Keyword': ['statistics book', 'statistics book', 'statistics book'],
    # Probability of click through rate (This is a guess as we don't have the actual data)
    'pCTR': [0.03, 0.04, 0.02],
    # Bid amount (this will be randomized around this central amount)
    'Bid': [0.5, 0.48, 0.55],
    'Budget': [5000,3000,2000],
}

# Create DataFrame
items_keywords_df = pd.DataFrame(data)

# Print DataFrame
display(items_keywords_df)
# Out:
#                                             Item          Keyword  pCTR   Bid  \
# 0  Time Series Analysis: Forecasting and Control  statistics book  0.03  0.50
# 1       Practical Statistics for Data Scientists  statistics book  0.04  0.48
# 2          Designing Data-Intensive Applications  statistics book  0.02  0.55
#
#    Budget
# 0    5000
# 1    3000
# 2    2000

# %%
# Simulate a bid around a keyword
   # This should will take modifiers from control algorithms
import numpy as np
def auction(df):
    """
    Gets df with bidding information and simulates an auction
    
    Returns winner and price paid
    
    """
    bid_dict = {}
    for index, id in df.iterrows():
        bid_dict[index] = id['Bid']- np.random.uniform(0.0, 0.2)
    winner = max(bid_dict, key=bid_dict.get)
    try:
        # price paid is the bid of the second highest bidder
        price_paid = sorted(bid_dict.values(), reverse=True)[1]
    except:
        # If there is only one bidder, the price paid is the bid of the winner
        price_paid = bid_dict[winner]
    return winner, price_paid

winner, price_paid = auction(items_keywords_df)
print(winner)
print(f"The winner is {items_keywords_df.loc[winner]['Item']}")
print(f"The price paid is {price_paid}")
# Out:
# 2
# The winner is Designing Data-Intensive Applications
# The price paid is 0.45676097052484843

# %%
def auction(df):
    """
    Gets df with bidding information and simulates an auction
    
    Returns winner's item name and price paid
    
    """
    bid_dict = {}
    for index, id in df.iterrows():
        bid_dict[index] = id['Bid'] - np.random.uniform(0.0, 0.2)
    winner_index = max(bid_dict, key=bid_dict.get)
    winner = df.loc[winner_index]['Item']
    try:
        # price paid is the bid of the second highest bidder
        price_paid = sorted(bid_dict.values(), reverse=True)[1]
    except:
        # If there is only one bidder, the price paid is the bid of the winner
        price_paid = bid_dict[winner_index]
    return winner, price_paid

winner, price_paid = auction(items_keywords_df)
print(f"The winner is {winner}")
print(f"The price paid is {price_paid}")
# Out:
# The winner is Practical Statistics for Data Scientists
# The price paid is 0.39375603943975823

# %%
test_df = items_keywords_df.copy()

def decide_budget_proportional_choice(Budget, Spend) -> int:
    """
    Choose a campaign based on the proportion of budget spent
    """
    p = (Budget - Spend) / Budget
    #ensure p is between 0 and 1
    p = max(0, min(1, p))
    return np.random.choice([0, 1], p=[1-p, p])

decide_budget_proportional_choice(1000, 500)

test_df['Enter_bid'] = test_df.apply(lambda x: decide_budget_proportional_choice(x['Budget'], x['Spend']), axis=1)
test_df[test_df['Enter_bid'] == 1]
# Out:
#                                             Item          Keyword  pCTR   Bid  \
# 0  Time Series Analysis: Forecasting and Control  statistics book  0.03  0.50
# 1       Practical Statistics for Data Scientists  statistics book  0.04  0.48
#
#    Budget        Spend  Enter_bid
# 0    5000  3664.188009          1
# 1    3000  2750.662544          1

# %%
# Add number of clicks, total spend, CTR, CPC
def calc_clicks(pCTR, total_impressions = 1000):
    return total_impressions * pCTR

def calc_total_spend(clicks, price_paid):
    return clicks * price_paid

# %%
# Simulate unlimited budget over 1440 minutes
# iterate over 1440 minutes (flat traffic)
# Save the winner and price paid
# Build a dataframe with the results

simulation_results = []
simulation_results.append({
            'Minute': 0,
            'Winner': 'Time Series Analysis: Forecasting and Control',
            'Price Paid': 0,
            "pCTR": 0,
            "Spend": 0,
        })
simulation_results_df = pd.DataFrame(simulation_results)
for minute in range(1440):
    # Remove winner if Spend is greater than Budget
    #items_keywords_df = items_keywords_df[items_keywords_df['Spend'] < items_keywords_df['Budget']]
    
    # Choose who enters the bid (% to budget strategy)
    
    selection_df = items_keywords_df.copy()
    
    # Update selection_df with Spend so far from dataframe simulation_results_df.groupby('Winner')['Spend'].sum()
    selection_df = pd.merge(selection_df, simulation_results_df.groupby('Winner')['Spend'].sum(), left_on='Item', right_on='Winner', how='left')
    
    
    selection_df['Enter_bid'] = selection_df.apply(lambda x: decide_budget_proportional_choice(x['Budget'], x['Spend']), axis=1)
    
    selection_df = selection_df[selection_df['Enter_bid'] == 1]  
    
    # If there are no bidders, skip the minute and save as "No Bid" 
    
    if selection_df.shape[0] == 0:
        print("# No Bidder")
        simulation_results.append({
            'Minute': minute,
            'Winner': 'No Bid',
            'Price Paid': 0,
            "pCTR": 0,
            "Spend": 0,
        })
            
    else:    
        print("# Bidding")
        winner_item, price_paid = auction(selection_df)
        winner_index = items_keywords_df[items_keywords_df['Item'] == winner_item].index[0]
        pctr = items_keywords_df.loc[winner_index]['pCTR'] + np.random.normal(-0.001, 0.01)
        result = {
            'Minute': minute,
            'Winner': items_keywords_df.loc[winner_index]['Item'],
            'Price Paid': price_paid,
            "pCTR": pctr,
            "Spend": price_paid * pctr * 1000
        }
        
        # Update Spend so far for the winner
        #items_keywords_df.loc[winner_index, 'Spend'] = items_keywords_df.loc[winner_index, 'Spend'] + result['Spend']
        
        # print winner and Spend
        print(f"Minute {minute}: {result['Winner']} wins with a bid of {price_paid}. Spend so far: {selection_df.loc[winner_index, 'Spend']}")
        
        
        simulation_results.append(result)
    simulation_results_df = pd.DataFrame(simulation_results)
    #print cumulative summ of spend per winner
    print(simulation_results_df.groupby('Winner')['Spend'].sum())
# Out:
# # Bidding
# Minute 0: Time Series Analysis: Forecasting and Control wins with a bid of 0.37426104146909733. Spend so far: 0.0
# Winner
# Time Series Analysis: Forecasting and Control    16.523405
# Name: Spend, dtype: float64
# # Bidding
# Minute 1: Designing Data-Intensive Applications wins with a bid of 0.3818696388102585. Spend so far: nan
# Winner
# Designing Data-Intensive Applications             9.440405
# Time Series Analysis: Forecasting and Control    16.523405
# Name: Spend, dtype: float64
# # Bidding
# Minute 2: Practical Statistics for Data Scientists wins with a bid of 0.37950965478963616. Spend so far: nan
# Winner
# Designing Data-Intensive Applications             9.440405
# Practical Statistics for Data Scientists         12.329444
# Time Series Analysis: Forecasting and Control    16.523405
# Name: Spend, dtype: float64
# # Bidding
# Minute 3: Time Series Analysis: Forecasting and Control wins with a bid of 0.3536753753015437. Spend so far: 16.52340489408784
# Winner
# Designing Data-Intensive Applications             9.440405
# Practical Statistics for Data Scientists         12.329444
# Time Series Analysis: Forecasting and Control    25.876817
# Name: Spend, dtype: float64
# # Bidding
# Minute 4: Designing Data-Intensive Applications wins with a bid of 0.34569023142552135. Spend so far: 9.440404607111748
# Winner
# Designing Data-Intensive Applications            19.637803
# Practical Statistics for Data Scientists         12.329444
# Time Series Analysis: Forecasting and Control    25.876817
# Name: Spend, dtype: float64
# # Bidding
# Minute 5: Designing Data-Intensive Applications wins with a bid of 0.455956961374534. Spend so far: 19.637802718910432
# Winner
# Designing Data-Intensive Applications            30.174515
# Practical Statistics for Data Scientists         12.329444
# Time Series Analysis: Forecasting and Control    25.876817
# Name: Spend, dtype: float64
# # Bidding
# Minute 6: Designing Data-Intensive Applications wins with a bid of 0.4940820775105512. Spend so far: 30.174515326150356
# Winner
# Designing Data-Intensive Applications            40.114691
# Practical Statistics for Data Scientists         12.329444
# Time Series Analysis: Forecasting and Control    25.876817
# Name: Spend, dtype: float64
# # Bidding
# Minute 7: Time Series Analysis: Forecasting and Control wins with a bid of 0.3960271742343462. Spend so far: 25.876816993543123
# Winner
# Designing Data-Intensive Applications            40.114691
# Practical Statistics for Data Scientists         12.329444
# Time Series Analysis: Forecasting and Control    39.154371
# Name: Spend, dtype: float64
# # Bidding
# Minute 8: Designing Data-Intensive Applications wins with a bid of 0.44722063534235196. Spend so far: 40.11469060499871
# Winner
# Designing Data-Intensive Applications            46.101132
# Practical Statistics for Data Scientists         12.329444
# Time Series Analysis: Forecasting and Control    39.154371
# Name: Spend, dtype: float64
# # Bidding
# Minute 9: Designing Data-Intensive Applications wins with a bid of 0.4637651774822441. Spend so far: 46.10113160973733
# Winner
# Designing Data-Intensive Applications            57.747186
# Practical Statistics for Data Scientists         12.329444
# Time Series Analysis: Forecasting and Control    39.154371
# Name: Spend, dtype: float64
# # Bidding
# Minute 10: Practical Statistics for Data Scientists wins with a bid of 0.3885163485457813. Spend so far: 12.32944413595717
# Winner
# Designing Data-Intensive Applications            57.747186
# Practical Statistics for Data Scientists         25.825631
# Time Series Analysis: Forecasting and Control    39.154371
# Name: Spend, dtype: float64
# # Bidding
# Minute 11: Designing Data-Intensive Applications wins with a bid of 0.4363849705256044. Spend so far: 57.7471860622166
# Winner
# Designing Data-Intensive Applications            60.844252
# Practical Statistics for Data Scientists         25.825631
# Time Series Analysis: Forecasting and Control    39.154371
# Name: Spend, dtype: float64
# # Bidding
# Minute 12: Designing Data-Intensive Applications wins with a bid of 0.45399652698281384. Spend so far: 60.84425203244826
# Winner
# Designing Data-Intensive Applications            67.818584
# Practical Statistics for Data Scientists         25.825631
# Time Series Analysis: Forecasting and Control    39.154371
# Name: Spend, dtype: float64
# # Bidding
# Minute 13: Time Series Analysis: Forecasting and Control wins with a bid of 0.37179944124837927. Spend so far: 39.154371263585524
# Winner
# Designing Data-Intensive Applications            67.818584
# Practical Statistics for Data Scientists         25.825631
# Time Series Analysis: Forecasting and Control    43.600109
# Name: Spend, dtype: float64
# # Bidding
# Minute 14: Time Series Analysis: Forecasting and Control wins with a bid of 0.3788749963511683. Spend so far: 43.60010903137355
# Winner
# Designing Data-Intensive Applications            67.818584
# Practical Statistics for Data Scientists         25.825631
# Time Series Analysis: Forecasting and Control    52.916919
# Name: Spend, dtype: float64
# # Bidding
# Minute 15: Designing Data-Intensive Applications wins with a bid of 0.3446036030188999. Spend so far: 67.81858392961169
# Winner
# Designing Data-Intensive Applications            78.537530
# Practical Statistics for Data Scientists         25.825631
# Time Series Analysis: Forecasting and Control    52.916919
# Name: Spend, dtype: float64
# # Bidding
# Minute 16: Designing Data-Intensive Applications wins with a bid of 0.4633127748962266. Spend so far: 78.53752960489952
# Winner
# Designing Data-Intensive Applications            81.024567
# Practical Statistics for Data Scientists         25.825631
# Time Series Analysis: Forecasting and Control    52.916919
# Name: Spend, dtype: float64
# # Bidding
# Minute 17: Time Series Analysis: Forecasting and Control wins with a bid of 0.4244246222415695. Spend so far: 52.916919154524706
# Winner
# Designing Data-Intensive Applications            81.024567
# Practical Statistics for Data Scientists         25.825631
# Time Series Analysis: Forecasting and Control    70.825941
# Name: Spend, dtype: float64
# # Bidding
# Minute 18: Designing Data-Intensive Applications wins with a bid of 0.4396499408752355. Spend so far: 81.02456711485463
# Winner
# Designing Data-Intensive Applications            87.311035
# Practical Statistics for Data Scientists         25.825631
# Time Series Analysis: Forecasting and Control    70.825941
# Name: Spend, dtype: float64
# # Bidding
# Minute 19: Time Series Analysis: Forecasting and Control wins with a bid of 0.4568453415443018. Spend so far: 70.82594060154267
# Winner
# Designing Data-Intensive Applications            87.311035
# Practical Statistics for Data Scientists         25.825631
# Time Series Analysis: Forecasting and Control    89.896787
# Name: Spend, dtype: float64
# # Bidding
# Minute 20: Designing Data-Intensive Applications wins with a bid of 0.4103682218665515. Spend so far: 87.31103523081221
# Winner
# Designing Data-Intensive Applications            97.391816
# Practical Statistics for Data Scientists         25.825631
# Time Series Analysis: Forecasting and Control    89.896787
# Name: Spend, dtype: float64
# # Bidding
# Minute 21: Practical Statistics for Data Scientists wins with a bid of 0.4512557303703748. Spend so far: 25.825631224694007
# Winner
# Designing Data-Intensive Applications            97.391816
# Practical Statistics for Data Scientists         37.567745
# Time Series Analysis: Forecasting and Control    89.896787
# Name: Spend, dtype: float64
# # Bidding
# Minute 22: Designing Data-Intensive Applications wins with a bid of 0.3558155571926987. Spend so far: 97.39181553233335
# Winner
# Designing Data-Intensive Applications            103.120512
# Practical Statistics for Data Scientists          37.567745
# Time Series Analysis: Forecasting and Control     89.896787
# Name: Spend, dtype: float64
# # Bidding
# Minute 23: Time Series Analysis: Forecasting and Control wins with a bid of 0.4279201528186503. Spend so far: 89.89678672454701
# Winner
# Designing Data-Intensive Applications            103.120512
# Practical Statistics for Data Scientists          37.567745
# Time Series Analysis: Forecasting and Control    100.123366
# Name: Spend, dtype: float64
# # Bidding
# Minute 24: Designing Data-Intensive Applications wins with a bid of 0.4551587531829137. Spend so far: 103.12051165390132
# Winner
# Designing Data-Intensive Applications            111.881963
# Practical Statistics for Data Scientists          37.567745
# Time Series Analysis: Forecasting and Control    100.123366
# Name: Spend, dtype: float64
# # Bidding
# Minute 25: Designing Data-Intensive Applications wins with a bid of 0.4308945887249912. Spend so far: 111.88196295692569
# Winner
# Designing Data-Intensive Applications            120.331902
# Practical Statistics for Data Scientists          37.567745
# Time Series Analysis: Forecasting and Control    100.123366
# Name: Spend, dtype: float64
# # Bidding
# Minute 26: Practical Statistics for Data Scientists wins with a bid of 0.4148697939523527. Spend so far: 37.56774480611413
# Winner
# Designing Data-Intensive Applications            120.331902
# Practical Statistics for Data Scientists          46.812160
# Time Series Analysis: Forecasting and Control    100.123366
# Name: Spend, dtype: float64
# # Bidding
# Minute 27: Designing Data-Intensive Applications wins with a bid of 0.36649539062918357. Spend so far: 120.33190202649286
# Winner
# Designing Data-Intensive Applications            123.566676
# Practical Statistics for Data Scientists          46.812160
# Time Series Analysis: Forecasting and Control    100.123366
# Name: Spend, dtype: float64
# # Bidding
# Minute 28: Time Series Analysis: Forecasting and Control wins with a bid of 0.4353978906614033. Spend so far: 100.12336553744514
# Winner
# Designing Data-Intensive Applications            123.566676
# Practical Statistics for Data Scientists          46.812160
# Time Series Analysis: Forecasting and Control    105.184558
# Name: Spend, dtype: float64
# # Bidding
# Minute 29: Designing Data-Intensive Applications wins with a bid of 0.3953421290158023. Spend so far: 123.56667605898699
# Winner
# Designing Data-Intensive Applications            130.388884
# Practical Statistics for Data Scientists          46.812160
# Time Series Analysis: Forecasting and Control    105.184558
# Name: Spend, dtype: float64
# # Bidding
# Minute 30: Designing Data-Intensive Applications wins with a bid of 0.4302069945875172. Spend so far: 130.38888366679927
# Winner
# Designing Data-Intensive Applications            142.305660
# Practical Statistics for Data Scientists          46.812160
# Time Series Analysis: Forecasting and Control    105.184558
# Name: Spend, dtype: float64
# # Bidding
# Minute 31: Designing Data-Intensive Applications wins with a bid of 0.34128805762887204. Spend so far: 142.30565976840512
# Winner
# Designing Data-Intensive Applications            151.294869
# Practical Statistics for Data Scientists          46.812160
# Time Series Analysis: Forecasting and Control    105.184558
# Name: Spend, dtype: float64
# # Bidding
# Minute 32: Designing Data-Intensive Applications wins with a bid of 0.4464529293091422. Spend so far: 151.2948687072802
# Winner
# Designing Data-Intensive Applications            156.431212
# Practical Statistics for Data Scientists          46.812160
# Time Series Analysis: Forecasting and Control    105.184558
# Name: Spend, dtype: float64
# # Bidding
# Minute 33: Practical Statistics for Data Scientists wins with a bid of 0.44652519896142545. Spend so far: 46.81215964634363
# Winner
# Designing Data-Intensive Applications            156.431212
# Practical Statistics for Data Scientists          66.916655
# Time Series Analysis: Forecasting and Control    105.184558
# Name: Spend, dtype: float64
# # Bidding
# Minute 34: Time Series Analysis: Forecasting and Control wins with a bid of 0.49005826327088386. Spend so far: 105.18455784220211
# Winner
# Designing Data-Intensive Applications            156.431212
# Practical Statistics for Data Scientists          66.916655
# Time Series Analysis: Forecasting and Control    115.961502
# Name: Spend, dtype: float64
# # Bidding
# Minute 35: Designing Data-Intensive Applications wins with a bid of 0.4531427576647645. Spend so far: 156.43121237564912
# Winner
# Designing Data-Intensive Applications            163.212527
# Practical Statistics for Data Scientists          66.916655
# Time Series Analysis: Forecasting and Control    115.961502
# Name: Spend, dtype: float64
# # Bidding
# Minute 36: Designing Data-Intensive Applications wins with a bid of 0.3511964967905251. Spend so far: 163.21252686196596
# Winner
# Designing Data-Intensive Applications            170.684091
# Practical Statistics for Data Scientists          66.916655
# Time Series Analysis: Forecasting and Control    115.961502
# Name: Spend, dtype: float64
# # Bidding
# Minute 37: Designing Data-Intensive Applications wins with a bid of 0.4130028128970683. Spend so far: 170.6840913027303
# Winner
# Designing Data-Intensive Applications            177.137482
# Practical Statistics for Data Scientists          66.916655
# Time Series Analysis: Forecasting and Control    115.961502
# Name: Spend, dtype: float64
# # Bidding
# Minute 38: Designing Data-Intensive Applications wins with a bid of 0.3649187219328832. Spend so far: 177.13748173507986
# Winner
# Designing Data-Intensive Applications            184.075277
# Practical Statistics for Data Scientists          66.916655
# Time Series Analysis: Forecasting and Control    115.961502
# Name: Spend, dtype: float64
# # Bidding
# Minute 39: Time Series Analysis: Forecasting and Control wins with a bid of 0.4201257113418756. Spend so far: 115.9615016937388
# Winner
# Designing Data-Intensive Applications            184.075277
# Practical Statistics for Data Scientists          66.916655
# Time Series Analysis: Forecasting and Control    122.250664
# Name: Spend, dtype: float64
# # Bidding
# Minute 40: Designing Data-Intensive Applications wins with a bid of 0.38346306148458825. Spend so far: 184.0752772790612
# Winner
# Designing Data-Intensive Applications            191.163222
# Practical Statistics for Data Scientists          66.916655
# Time Series Analysis: Forecasting and Control    122.250664
# Name: Spend, dtype: float64
# # Bidding
# Minute 41: Designing Data-Intensive Applications wins with a bid of 0.35156059912179777. Spend so far: 191.16322185283275
# Winner
# Designing Data-Intensive Applications            199.372399
# Practical Statistics for Data Scientists          66.916655
# Time Series Analysis: Forecasting and Control    122.250664
# Name: Spend, dtype: float64
# # Bidding
# Minute 42: Practical Statistics for Data Scientists wins with a bid of 0.42079078796064756. Spend so far: 66.9166554433425
# Winner
# Designing Data-Intensive Applications            199.372399
# Practical Statistics for Data Scientists          85.214695
# Time Series Analysis: Forecasting and Control    122.250664
# Name: Spend, dtype: float64
# # Bidding
# Minute 43: Designing Data-Intensive Applications wins with a bid of 0.44273008246602497. Spend so far: 199.3723985487341
# Winner
# Designing Data-Intensive Applications            204.951741
# Practical Statistics for Data Scientists          85.214695
# Time Series Analysis: Forecasting and Control    122.250664
# Name: Spend, dtype: float64
# # Bidding
# Minute 44: Designing Data-Intensive Applications wins with a bid of 0.3720583738640569. Spend so far: 204.95174063701538
# Winner
# Designing Data-Intensive Applications            216.049341
# Practical Statistics for Data Scientists          85.214695
# Time Series Analysis: Forecasting and Control    122.250664
# Name: Spend, dtype: float64
# # Bidding
# Minute 45: Practical Statistics for Data Scientists wins with a bid of 0.41398872765507466. Spend so far: 85.21469459027387
# Winner
# Designing Data-Intensive Applications            216.049341
# Practical Statistics for Data Scientists          94.667034
# Time Series Analysis: Forecasting and Control    122.250664
# Name: Spend, dtype: float64
# # Bidding
# Minute 46: Designing Data-Intensive Applications wins with a bid of 0.46578769788767516. Spend so far: 216.04934096190433
# Winner
# Designing Data-Intensive Applications            226.241280
# Practical Statistics for Data Scientists          94.667034
# Time Series Analysis: Forecasting and Control    122.250664
# Name: Spend, dtype: float64
# # Bidding
# Minute 47: Practical Statistics for Data Scientists wins with a bid of 0.39979918108906487. Spend so far: 94.66703360904113
# Winner
# Designing Data-Intensive Applications            226.241280
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    122.250664
# Name: Spend, dtype: float64
# # Bidding
# Minute 48: Designing Data-Intensive Applications wins with a bid of 0.28311693091262946. Spend so far: 226.24128036269724
# Winner
# Designing Data-Intensive Applications            233.362342
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    122.250664
# Name: Spend, dtype: float64
# # Bidding
# Minute 49: Designing Data-Intensive Applications wins with a bid of 0.4915347577487438. Spend so far: 233.36234220173412
# Winner
# Designing Data-Intensive Applications            234.583771
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    122.250664
# Name: Spend, dtype: float64
# # Bidding
# Minute 50: Designing Data-Intensive Applications wins with a bid of 0.456816782113166. Spend so far: 234.58377112048268
# Winner
# Designing Data-Intensive Applications            242.591189
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    122.250664
# Name: Spend, dtype: float64
# # Bidding
# Minute 51: Designing Data-Intensive Applications wins with a bid of 0.4173946704641897. Spend so far: 242.59118888654766
# Winner
# Designing Data-Intensive Applications            243.013043
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    122.250664
# Name: Spend, dtype: float64
# # Bidding
# Minute 52: Time Series Analysis: Forecasting and Control wins with a bid of 0.4412179254055225. Spend so far: 122.25066400174222
# Winner
# Designing Data-Intensive Applications            243.013043
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    131.657518
# Name: Spend, dtype: float64
# # Bidding
# Minute 53: Designing Data-Intensive Applications wins with a bid of 0.3536318895605224. Spend so far: 243.01304291617683
# Winner
# Designing Data-Intensive Applications            248.809047
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    131.657518
# Name: Spend, dtype: float64
# # Bidding
# Minute 54: Time Series Analysis: Forecasting and Control wins with a bid of 0.4224320926383586. Spend so far: 131.65751822815565
# Winner
# Designing Data-Intensive Applications            248.809047
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    145.299645
# Name: Spend, dtype: float64
# # Bidding
# Minute 55: Designing Data-Intensive Applications wins with a bid of 0.4655173350361702. Spend so far: 248.8090468360674
# Winner
# Designing Data-Intensive Applications            264.922411
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    145.299645
# Name: Spend, dtype: float64
# # Bidding
# Minute 56: Designing Data-Intensive Applications wins with a bid of 0.46374076427324484. Spend so far: 264.92241074696943
# Winner
# Designing Data-Intensive Applications            279.675007
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    145.299645
# Name: Spend, dtype: float64
# # Bidding
# Minute 57: Time Series Analysis: Forecasting and Control wins with a bid of 0.4441071463893209. Spend so far: 145.29964523638583
# Winner
# Designing Data-Intensive Applications            279.675007
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    154.393578
# Name: Spend, dtype: float64
# # Bidding
# Minute 58: Designing Data-Intensive Applications wins with a bid of 0.37066531672062597. Spend so far: 279.67500691977597
# Winner
# Designing Data-Intensive Applications            291.318573
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    154.393578
# Name: Spend, dtype: float64
# # Bidding
# Minute 59: Designing Data-Intensive Applications wins with a bid of 0.3466874861736745. Spend so far: 291.3185731936257
# Winner
# Designing Data-Intensive Applications            304.406525
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    154.393578
# Name: Spend, dtype: float64
# # Bidding
# Minute 60: Designing Data-Intensive Applications wins with a bid of 0.4241635310430034. Spend so far: 304.40652484496513
# Winner
# Designing Data-Intensive Applications            305.490111
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    154.393578
# Name: Spend, dtype: float64
# # Bidding
# Minute 61: Designing Data-Intensive Applications wins with a bid of 0.3719401788751718. Spend so far: 305.4901114023349
# Winner
# Designing Data-Intensive Applications            312.898594
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    154.393578
# Name: Spend, dtype: float64
# # Bidding
# Minute 62: Time Series Analysis: Forecasting and Control wins with a bid of 0.3831773533892204. Spend so far: 154.39357752498523
# Winner
# Designing Data-Intensive Applications            312.898594
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    165.365465
# Name: Spend, dtype: float64
# # Bidding
# Minute 63: Time Series Analysis: Forecasting and Control wins with a bid of 0.35448030918189277. Spend so far: 165.36546517167005
# Winner
# Designing Data-Intensive Applications            312.898594
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    179.998885
# Name: Spend, dtype: float64
# # Bidding
# Minute 64: Designing Data-Intensive Applications wins with a bid of 0.41899930594005197. Spend so far: 312.8985939883917
# Winner
# Designing Data-Intensive Applications            318.585754
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    179.998885
# Name: Spend, dtype: float64
# # Bidding
# Minute 65: Time Series Analysis: Forecasting and Control wins with a bid of 0.4342811957089237. Spend so far: 179.99888533729919
# Winner
# Designing Data-Intensive Applications            318.585754
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    191.452572
# Name: Spend, dtype: float64
# # Bidding
# Minute 66: Time Series Analysis: Forecasting and Control wins with a bid of 0.3937974197060607. Spend so far: 191.4525723659241
# Winner
# Designing Data-Intensive Applications            318.585754
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    206.251519
# Name: Spend, dtype: float64
# # Bidding
# Minute 67: Designing Data-Intensive Applications wins with a bid of 0.4414717173311878. Spend so far: 318.5857537697681
# Winner
# Designing Data-Intensive Applications            320.344109
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    206.251519
# Name: Spend, dtype: float64
# # Bidding
# Minute 68: Designing Data-Intensive Applications wins with a bid of 0.43624475447553834. Spend so far: 320.34410851235083
# Winner
# Designing Data-Intensive Applications            332.989101
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    206.251519
# Name: Spend, dtype: float64
# # Bidding
# Minute 69: Designing Data-Intensive Applications wins with a bid of 0.432336329296756. Spend so far: 332.98910131741417
# Winner
# Designing Data-Intensive Applications            342.009351
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    206.251519
# Name: Spend, dtype: float64
# # Bidding
# Minute 70: Designing Data-Intensive Applications wins with a bid of 0.445389878481767. Spend so far: 342.0093506583007
# Winner
# Designing Data-Intensive Applications            344.025109
# Practical Statistics for Data Scientists         115.357385
# Time Series Analysis: Forecasting and Control    206.251519
# Name: Spend, dtype: float64
# # Bidding
# Minute 71: Practical Statistics for Data Scientists wins with a bid of 0.4062742863015831. Spend so far: 115.3573854934283
# Winner
# Designing Data-Intensive Applications            344.025109
# Practical Statistics for Data Scientists         131.974217
# Time Series Analysis: Forecasting and Control    206.251519
# Name: Spend, dtype: float64
# # Bidding
# Minute 72: Designing Data-Intensive Applications wins with a bid of 0.45688938764411385. Spend so far: 344.0251085150239
# Winner
# Designing Data-Intensive Applications            358.846416
# Practical Statistics for Data Scientists         131.974217
# Time Series Analysis: Forecasting and Control    206.251519
# Name: Spend, dtype: float64
# # Bidding
# Minute 73: Designing Data-Intensive Applications wins with a bid of 0.31352809037083185. Spend so far: 358.8464164521768
# Winner
# Designing Data-Intensive Applications            365.676683
# Practical Statistics for Data Scientists         131.974217
# Time Series Analysis: Forecasting and Control    206.251519
# Name: Spend, dtype: float64
# # Bidding
# Minute 74: Time Series Analysis: Forecasting and Control wins with a bid of 0.4316139237901964. Spend so far: 206.25151907922833
# Winner
# Designing Data-Intensive Applications            365.676683
# Practical Statistics for Data Scientists         131.974217
# Time Series Analysis: Forecasting and Control    220.344982
# Name: Spend, dtype: float64
# # Bidding
# Minute 75: Time Series Analysis: Forecasting and Control wins with a bid of 0.36994378301077696. Spend so far: 220.34498201917322
# Winner
# Designing Data-Intensive Applications            365.676683
# Practical Statistics for Data Scientists         131.974217
# Time Series Analysis: Forecasting and Control    228.694270
# Name: Spend, dtype: float64
# # Bidding
# Minute 76: Designing Data-Intensive Applications wins with a bid of 0.49465652287158934. Spend so far: 365.67668254258115
# Winner
# Designing Data-Intensive Applications            372.882947
# Practical Statistics for Data Scientists         131.974217
# Time Series Analysis: Forecasting and Control    228.694270
# Name: Spend, dtype: float64
# # Bidding
# Minute 77: Designing Data-Intensive Applications wins with a bid of 0.36081595448907866. Spend so far: 372.88294718197466
# Winner
# Designing Data-Intensive Applications            383.715131
# Practical Statistics for Data Scientists         131.974217
# Time Series Analysis: Forecasting and Control    228.694270
# Name: Spend, dtype: float64
# # Bidding
# Minute 78: Designing Data-Intensive Applications wins with a bid of 0.4634158803853374. Spend so far: 383.7151310666274
# Winner
# Designing Data-Intensive Applications            394.294625
# Practical Statistics for Data Scientists         131.974217
# Time Series Analysis: Forecasting and Control    228.694270
# Name: Spend, dtype: float64
# # Bidding
# Minute 79: Time Series Analysis: Forecasting and Control wins with a bid of 0.4000267427864219. Spend so far: 228.69426979932535
# Winner
# Designing Data-Intensive Applications            394.294625
# Practical Statistics for Data Scientists         131.974217
# Time Series Analysis: Forecasting and Control    236.419795
# Name: Spend, dtype: float64
# # Bidding
# Minute 80: Time Series Analysis: Forecasting and Control wins with a bid of 0.4719676957056938. Spend so far: 236.4197948517927
# Winner
# Designing Data-Intensive Applications            394.294625
# Practical Statistics for Data Scientists         131.974217
# Time Series Analysis: Forecasting and Control    253.723569
# Name: Spend, dtype: float64
# # Bidding
# Minute 81: Designing Data-Intensive Applications wins with a bid of 0.47688921835344156. Spend so far: 394.2946252638842
# Winner
# Designing Data-Intensive Applications            410.693270
# Practical Statistics for Data Scientists         131.974217
# Time Series Analysis: Forecasting and Control    253.723569
# Name: Spend, dtype: float64
# # Bidding
# Minute 82: Designing Data-Intensive Applications wins with a bid of 0.33978686985025136. Spend so far: 410.6932699634264
# Winner
# Designing Data-Intensive Applications            416.686269
# Practical Statistics for Data Scientists         131.974217
# Time Series Analysis: Forecasting and Control    253.723569
# Name: Spend, dtype: float64
# # Bidding
# Minute 83: Designing Data-Intensive Applications wins with a bid of 0.4440402930111313. Spend so far: 416.686268552601
# Winner
# Designing Data-Intensive Applications            426.857316
# Practical Statistics for Data Scientists         131.974217
# Time Series Analysis: Forecasting and Control    253.723569
# Name: Spend, dtype: float64
# # Bidding
# Minute 84: Designing Data-Intensive Applications wins with a bid of 0.3876027086711522. Spend so far: 426.8573163625009
# Winner
# Designing Data-Intensive Applications            436.837909
# Practical Statistics for Data Scientists         131.974217
# Time Series Analysis: Forecasting and Control    253.723569
# Name: Spend, dtype: float64
# # Bidding
# Minute 85: Designing Data-Intensive Applications wins with a bid of 0.4170339339232333. Spend so far: 436.8379091410612
# Winner
# Designing Data-Intensive Applications            444.957243
# Practical Statistics for Data Scientists         131.974217
# Time Series Analysis: Forecasting and Control    253.723569
# Name: Spend, dtype: float64
# # Bidding
# Minute 86: Designing Data-Intensive Applications wins with a bid of 0.3672161671881817. Spend so far: 444.9572433268379
# Winner
# Designing Data-Intensive Applications            451.689376
# Practical Statistics for Data Scientists         131.974217
# Time Series Analysis: Forecasting and Control    253.723569
# Name: Spend, dtype: float64
# # Bidding
# Minute 87: Practical Statistics for Data Scientists wins with a bid of 0.4572678487429186. Spend so far: 131.97421704394014
# Winner
# Designing Data-Intensive Applications            451.689376
# Practical Statistics for Data Scientists         156.030527
# Time Series Analysis: Forecasting and Control    253.723569
# Name: Spend, dtype: float64
# # Bidding
# Minute 88: Time Series Analysis: Forecasting and Control wins with a bid of 0.2899994474031664. Spend so far: 253.72356937751343
# Winner
# Designing Data-Intensive Applications            451.689376
# Practical Statistics for Data Scientists         156.030527
# Time Series Analysis: Forecasting and Control    261.093710
# Name: Spend, dtype: float64
# # Bidding
# Minute 89: Time Series Analysis: Forecasting and Control wins with a bid of 0.341808722338241. Spend so far: 261.0937097327164
# Winner
# Designing Data-Intensive Applications            451.689376
# Practical Statistics for Data Scientists         156.030527
# Time Series Analysis: Forecasting and Control    272.166616
# Name: Spend, dtype: float64
# # Bidding
# Minute 90: Designing Data-Intensive Applications wins with a bid of 0.3527535115615158. Spend so far: 451.68937586419935
# Winner
# Designing Data-Intensive Applications            460.447877
# Practical Statistics for Data Scientists         156.030527
# Time Series Analysis: Forecasting and Control    272.166616
# Name: Spend, dtype: float64
# # Bidding
# Minute 91: Time Series Analysis: Forecasting and Control wins with a bid of 0.4241225087963416. Spend so far: 272.1666164845206
# Winner
# Designing Data-Intensive Applications            460.447877
# Practical Statistics for Data Scientists         156.030527
# Time Series Analysis: Forecasting and Control    286.217477
# Name: Spend, dtype: float64
# # Bidding
# Minute 92: Time Series Analysis: Forecasting and Control wins with a bid of 0.30558857451546784. Spend so far: 286.2174769016547
# Winner
# Designing Data-Intensive Applications            460.447877
# Practical Statistics for Data Scientists         156.030527
# Time Series Analysis: Forecasting and Control    292.231149
# Name: Spend, dtype: float64
# # Bidding
# Minute 93: Designing Data-Intensive Applications wins with a bid of 0.42655568689710155. Spend so far: 460.4478768425878
# Winner
# Designing Data-Intensive Applications            469.014577
# Practical Statistics for Data Scientists         156.030527
# Time Series Analysis: Forecasting and Control    292.231149
# Name: Spend, dtype: float64
# # Bidding
# Minute 94: Time Series Analysis: Forecasting and Control wins with a bid of 0.3944775959045257. Spend so far: 292.23114854264935
# Winner
# Designing Data-Intensive Applications            469.014577
# Practical Statistics for Data Scientists         156.030527
# Time Series Analysis: Forecasting and Control    303.540960
# Name: Spend, dtype: float64
# # Bidding
# Minute 95: Time Series Analysis: Forecasting and Control wins with a bid of 0.47700197748791984. Spend so far: 303.5409602978072
# Winner
# Designing Data-Intensive Applications            469.014577
# Practical Statistics for Data Scientists         156.030527
# Time Series Analysis: Forecasting and Control    313.050149
# Name: Spend, dtype: float64
# # Bidding
# Minute 96: Time Series Analysis: Forecasting and Control wins with a bid of 0.3582594434502231. Spend so far: 313.05014863214546
# Winner
# Designing Data-Intensive Applications            469.014577
# Practical Statistics for Data Scientists         156.030527
# Time Series Analysis: Forecasting and Control    321.785375
# Name: Spend, dtype: float64
# # Bidding
# Minute 97: Designing Data-Intensive Applications wins with a bid of 0.4780727010028666. Spend so far: 469.0145772431025
# Winner
# Designing Data-Intensive Applications            471.653826
# Practical Statistics for Data Scientists         156.030527
# Time Series Analysis: Forecasting and Control    321.785375
# Name: Spend, dtype: float64
# # Bidding
# Minute 98: Practical Statistics for Data Scientists wins with a bid of 0.3430776278069568. Spend so far: 156.03052670785843
# Winner
# Designing Data-Intensive Applications            471.653826
# Practical Statistics for Data Scientists         164.851980
# Time Series Analysis: Forecasting and Control    321.785375
# Name: Spend, dtype: float64
# # Bidding
# Minute 99: Designing Data-Intensive Applications wins with a bid of 0.34810351140329066. Spend so far: 471.65382573859307
# Winner
# Designing Data-Intensive Applications            473.239191
# Practical Statistics for Data Scientists         164.851980
# Time Series Analysis: Forecasting and Control    321.785375
# Name: Spend, dtype: float64
# # Bidding
# Minute 100: Time Series Analysis: Forecasting and Control wins with a bid of 0.38959712562608445. Spend so far: 321.7853748468669
# Winner
# Designing Data-Intensive Applications            473.239191
# Practical Statistics for Data Scientists         164.851980
# Time Series Analysis: Forecasting and Control    335.109407
# Name: Spend, dtype: float64
# # Bidding
# Minute 101: Time Series Analysis: Forecasting and Control wins with a bid of 0.40644525543220134. Spend so far: 335.10940742736756
# Winner
# Designing Data-Intensive Applications            473.239191
# Practical Statistics for Data Scientists         164.851980
# Time Series Analysis: Forecasting and Control    347.690823
# Name: Spend, dtype: float64
# # Bidding
# Minute 102: Designing Data-Intensive Applications wins with a bid of 0.35254085938018664. Spend so far: 473.239190968605
# Winner
# Designing Data-Intensive Applications            478.292115
# Practical Statistics for Data Scientists         164.851980
# Time Series Analysis: Forecasting and Control    347.690823
# Name: Spend, dtype: float64
# # Bidding
# Minute 103: Designing Data-Intensive Applications wins with a bid of 0.44345366441512946. Spend so far: 478.29211469807774
# Winner
# Designing Data-Intensive Applications            481.140846
# Practical Statistics for Data Scientists         164.851980
# Time Series Analysis: Forecasting and Control    347.690823
# Name: Spend, dtype: float64
# # Bidding
# Minute 104: Time Series Analysis: Forecasting and Control wins with a bid of 0.42039625508653855. Spend so far: 347.690823396371
# Winner
# Designing Data-Intensive Applications            481.140846
# Practical Statistics for Data Scientists         164.851980
# Time Series Analysis: Forecasting and Control    354.783855
# Name: Spend, dtype: float64
# # Bidding
# Minute 105: Time Series Analysis: Forecasting and Control wins with a bid of 0.31687547907512836. Spend so far: 354.7838550084586
# Winner
# Designing Data-Intensive Applications            481.140846
# Practical Statistics for Data Scientists         164.851980
# Time Series Analysis: Forecasting and Control    367.419731
# Name: Spend, dtype: float64
# # Bidding
# Minute 106: Practical Statistics for Data Scientists wins with a bid of 0.3204122818787497. Spend so far: 164.85198042328338
# Winner
# Designing Data-Intensive Applications            481.140846
# Practical Statistics for Data Scientists         180.618870
# Time Series Analysis: Forecasting and Control    367.419731
# Name: Spend, dtype: float64
# # Bidding
# Minute 107: Designing Data-Intensive Applications wins with a bid of 0.37269698518176925. Spend so far: 481.1408461748569
# Winner
# Designing Data-Intensive Applications            491.600086
# Practical Statistics for Data Scientists         180.618870
# Time Series Analysis: Forecasting and Control    367.419731
# Name: Spend, dtype: float64
# # Bidding
# Minute 108: Designing Data-Intensive Applications wins with a bid of 0.49719862444868224. Spend so far: 491.6000856488193
# Winner
# Designing Data-Intensive Applications            492.806738
# Practical Statistics for Data Scientists         180.618870
# Time Series Analysis: Forecasting and Control    367.419731
# Name: Spend, dtype: float64
# # Bidding
# Minute 109: Designing Data-Intensive Applications wins with a bid of 0.4306333106390883. Spend so far: 492.8067376481421
# Winner
# Designing Data-Intensive Applications            506.971973
# Practical Statistics for Data Scientists         180.618870
# Time Series Analysis: Forecasting and Control    367.419731
# Name: Spend, dtype: float64
# # Bidding
# Minute 110: Designing Data-Intensive Applications wins with a bid of 0.34756303926935594. Spend so far: 506.9719726301937
# Winner
# Designing Data-Intensive Applications            512.564373
# Practical Statistics for Data Scientists         180.618870
# Time Series Analysis: Forecasting and Control    367.419731
# Name: Spend, dtype: float64
# # Bidding
# Minute 111: Designing Data-Intensive Applications wins with a bid of 0.3632228302365771. Spend so far: 512.5643730201429
# Winner
# Designing Data-Intensive Applications            515.002393
# Practical Statistics for Data Scientists         180.618870
# Time Series Analysis: Forecasting and Control    367.419731
# Name: Spend, dtype: float64
# # Bidding
# Minute 112: Practical Statistics for Data Scientists wins with a bid of 0.38155060369369886. Spend so far: 180.6188695161025
# Winner
# Designing Data-Intensive Applications            515.002393
# Practical Statistics for Data Scientists         193.906906
# Time Series Analysis: Forecasting and Control    367.419731
# Name: Spend, dtype: float64
# # Bidding
# Minute 113: Time Series Analysis: Forecasting and Control wins with a bid of 0.439415804503021. Spend so far: 367.41973134104046
# Winner
# Designing Data-Intensive Applications            515.002393
# Practical Statistics for Data Scientists         193.906906
# Time Series Analysis: Forecasting and Control    390.238740
# Name: Spend, dtype: float64
# # Bidding
# Minute 114: Practical Statistics for Data Scientists wins with a bid of 0.44622173328883125. Spend so far: 193.90690561860845
# Winner
# Designing Data-Intensive Applications            515.002393
# Practical Statistics for Data Scientists         202.095962
# Time Series Analysis: Forecasting and Control    390.238740
# Name: Spend, dtype: float64
# # Bidding
# Minute 115: Designing Data-Intensive Applications wins with a bid of 0.4373196270135824. Spend so far: 515.0023933271912
# Winner
# Designing Data-Intensive Applications            524.018104
# Practical Statistics for Data Scientists         202.095962
# Time Series Analysis: Forecasting and Control    390.238740
# Name: Spend, dtype: float64
# # Bidding
# Minute 116: Time Series Analysis: Forecasting and Control wins with a bid of 0.36525848178127945. Spend so far: 390.2387402805047
# Winner
# Designing Data-Intensive Applications            524.018104
# Practical Statistics for Data Scientists         202.095962
# Time Series Analysis: Forecasting and Control    400.884882
# Name: Spend, dtype: float64
# # Bidding
# Minute 117: Designing Data-Intensive Applications wins with a bid of 0.32466754553957855. Spend so far: 524.0181041610928
# Winner
# Designing Data-Intensive Applications            533.038007
# Practical Statistics for Data Scientists         202.095962
# Time Series Analysis: Forecasting and Control    400.884882
# Name: Spend, dtype: float64
# # Bidding
# Minute 118: Time Series Analysis: Forecasting and Control wins with a bid of 0.37079309428176743. Spend so far: 400.88488197389677
# Winner
# Designing Data-Intensive Applications            533.038007
# Practical Statistics for Data Scientists         202.095962
# Time Series Analysis: Forecasting and Control    412.893144
# Name: Spend, dtype: float64
# # Bidding
# Minute 119: Time Series Analysis: Forecasting and Control wins with a bid of 0.33669200322083426. Spend so far: 412.893143978269
# Winner
# Designing Data-Intensive Applications            533.038007
# Practical Statistics for Data Scientists         202.095962
# Time Series Analysis: Forecasting and Control    422.975332
# Name: Spend, dtype: float64
# # Bidding
# Minute 120: Designing Data-Intensive Applications wins with a bid of 0.49974761578514365. Spend so far: 533.0380070960633
# Winner
# Designing Data-Intensive Applications            534.912963
# Practical Statistics for Data Scientists         202.095962
# Time Series Analysis: Forecasting and Control    422.975332
# Name: Spend, dtype: float64
# # Bidding
# Minute 121: Time Series Analysis: Forecasting and Control wins with a bid of 0.3750647005815464. Spend so far: 422.97533223379986
# Winner
# Designing Data-Intensive Applications            534.912963
# Practical Statistics for Data Scientists         202.095962
# Time Series Analysis: Forecasting and Control    436.583403
# Name: Spend, dtype: float64
# # Bidding
# Minute 122: Designing Data-Intensive Applications wins with a bid of 0.3728255652824895. Spend so far: 534.9129633331253
# Winner
# Designing Data-Intensive Applications            542.082257
# Practical Statistics for Data Scientists         202.095962
# Time Series Analysis: Forecasting and Control    436.583403
# Name: Spend, dtype: float64
# # Bidding
# Minute 123: Designing Data-Intensive Applications wins with a bid of 0.40356303781341185. Spend so far: 542.0822565286193
# Winner
# Designing Data-Intensive Applications            546.578234
# Practical Statistics for Data Scientists         202.095962
# Time Series Analysis: Forecasting and Control    436.583403
# Name: Spend, dtype: float64
# # Bidding
# Minute 124: Time Series Analysis: Forecasting and Control wins with a bid of 0.41943182920421745. Spend so far: 436.58340285074263
# Winner
# Designing Data-Intensive Applications            546.578234
# Practical Statistics for Data Scientists         202.095962
# Time Series Analysis: Forecasting and Control    454.074716
# Name: Spend, dtype: float64
# # Bidding
# Minute 125: Practical Statistics for Data Scientists wins with a bid of 0.359687261048968. Spend so far: 202.0959622357193
# Winner
# Designing Data-Intensive Applications            546.578234
# Practical Statistics for Data Scientists         215.520599
# Time Series Analysis: Forecasting and Control    454.074716
# Name: Spend, dtype: float64
# # Bidding
# Minute 126: Time Series Analysis: Forecasting and Control wins with a bid of 0.3615381731299417. Spend so far: 454.07471561744256
# Winner
# Designing Data-Intensive Applications            546.578234
# Practical Statistics for Data Scientists         215.520599
# Time Series Analysis: Forecasting and Control    460.855486
# Name: Spend, dtype: float64
# # Bidding
# Minute 127: Designing Data-Intensive Applications wins with a bid of 0.4010313984355848. Spend so far: 546.5782344168272
# Winner
# Designing Data-Intensive Applications            554.044265
# Practical Statistics for Data Scientists         215.520599
# Time Series Analysis: Forecasting and Control    460.855486
# Name: Spend, dtype: float64
# # Bidding
# Minute 128: Designing Data-Intensive Applications wins with a bid of 0.45631160619800143. Spend so far: 554.0442649234135
# Winner
# Designing Data-Intensive Applications            562.287965
# Practical Statistics for Data Scientists         215.520599
# Time Series Analysis: Forecasting and Control    460.855486
# Name: Spend, dtype: float64
# # Bidding
# Minute 129: Designing Data-Intensive Applications wins with a bid of 0.397736748446123. Spend so far: 562.2879647155103
# Winner
# Designing Data-Intensive Applications            560.682524
# Practical Statistics for Data Scientists         215.520599
# Time Series Analysis: Forecasting and Control    460.855486
# Name: Spend, dtype: float64
# # Bidding
# Minute 130: Time Series Analysis: Forecasting and Control wins with a bid of 0.42097524098307454. Spend so far: 460.8554856060201
# Winner
# Designing Data-Intensive Applications            560.682524
# Practical Statistics for Data Scientists         215.520599
# Time Series Analysis: Forecasting and Control    477.585820
# Name: Spend, dtype: float64
# # Bidding
# Minute 131: Practical Statistics for Data Scientists wins with a bid of 0.4249912317104244. Spend so far: 215.52059883309772
# Winner
# Designing Data-Intensive Applications            560.682524
# Practical Statistics for Data Scientists         227.277573
# Time Series Analysis: Forecasting and Control    477.585820
# Name: Spend, dtype: float64
# # Bidding
# Minute 132: Designing Data-Intensive Applications wins with a bid of 0.3860831287045497. Spend so far: 560.6825235275248
# Winner
# Designing Data-Intensive Applications            566.048577
# Practical Statistics for Data Scientists         227.277573
# Time Series Analysis: Forecasting and Control    477.585820
# Name: Spend, dtype: float64
# # Bidding
# Minute 133: Designing Data-Intensive Applications wins with a bid of 0.42060118248683664. Spend so far: 566.0485774908022
# Winner
# Designing Data-Intensive Applications            570.141805
# Practical Statistics for Data Scientists         227.277573
# Time Series Analysis: Forecasting and Control    477.585820
# Name: Spend, dtype: float64
# # Bidding
# Minute 134: Time Series Analysis: Forecasting and Control wins with a bid of 0.4287402001657912. Spend so far: 477.58581959255264
# Winner
# Designing Data-Intensive Applications            570.141805
# Practical Statistics for Data Scientists         227.277573
# Time Series Analysis: Forecasting and Control    484.554044
# Name: Spend, dtype: float64
# # Bidding
# Minute 135: Practical Statistics for Data Scientists wins with a bid of 0.45990932581825283. Spend so far: 227.27757284270123
# Winner
# Designing Data-Intensive Applications            570.141805
# Practical Statistics for Data Scientists         249.134158
# Time Series Analysis: Forecasting and Control    484.554044
# Name: Spend, dtype: float64
# # Bidding
# Minute 136: Designing Data-Intensive Applications wins with a bid of 0.4218698737839861. Spend so far: 570.1418047640564
# Winner
# Designing Data-Intensive Applications            573.849761
# Practical Statistics for Data Scientists         249.134158
# Time Series Analysis: Forecasting and Control    484.554044
# Name: Spend, dtype: float64
# # Bidding
# Minute 137: Time Series Analysis: Forecasting and Control wins with a bid of 0.287521617217428. Spend so far: 484.5540441233171
# Winner
# Designing Data-Intensive Applications            573.849761
# Practical Statistics for Data Scientists         249.134158
# Time Series Analysis: Forecasting and Control    494.984263
# Name: Spend, dtype: float64
# # Bidding
# Minute 138: Practical Statistics for Data Scientists wins with a bid of 0.30106466642999374. Spend so far: 249.13415756847334
# Winner
# ...
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4516.555992
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4516.555992
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4516.555992
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4516.555992
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4516.555992
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4516.555992
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4516.555992
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4516.555992
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4516.555992
# Name: Spend, dtype: float64
# # Bidding
# Minute 1396: Time Series Analysis: Forecasting and Control wins with a bid of 0.45253414628087896. Spend so far: 4516.555991853648
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4537.637607
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4537.637607
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4537.637607
# Name: Spend, dtype: float64
# # Bidding
# Minute 1399: Time Series Analysis: Forecasting and Control wins with a bid of 0.4599904126166349. Spend so far: 4537.637607420727
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4549.383840
# Name: Spend, dtype: float64
# # Bidding
# Minute 1434: Time Series Analysis: Forecasting and Control wins with a bid of 0.4544632981097507. Spend so far: 4549.383840082907
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4561.388429
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4561.388429
# Name: Spend, dtype: float64
# # Bidding
# Minute 1436: Time Series Analysis: Forecasting and Control wins with a bid of 0.47636132477389315. Spend so far: 4561.388429277817
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4585.829240
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4585.829240
# Name: Spend, dtype: float64
# # No Bidder
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4585.829240
# Name: Spend, dtype: float64
# # Bidding
# Minute 1439: Time Series Analysis: Forecasting and Control wins with a bid of 0.4713699003164663. Spend so far: 4585.829240187415
# Winner
# Designing Data-Intensive Applications            2000.289600
# No Bid                                              0.000000
# Practical Statistics for Data Scientists         2935.939988
# Time Series Analysis: Forecasting and Control    4595.904614
# Name: Spend, dtype: float64

# %%
selection_df
# Out:
#                                             Item          Keyword  pCTR  Bid  \
# 0  Time Series Analysis: Forecasting and Control  statistics book  0.03  0.5
#
#    Budget       Spend  Enter_bid
# 0    5000  4585.82924          1

# %%
simulation_results_df.groupby("Winner").agg({"Price Paid": "mean", "pCTR": "mean", "Minute": "count"})
# Out:
#                                                Price Paid      pCTR  Minute
# Winner
# Designing Data-Intensive Applications            0.404176  0.019651     253
# No Bid                                           0.000000  0.000000     600
# Practical Statistics for Data Scientists         0.381437  0.039863     193
# Time Series Analysis: Forecasting and Control    0.392213  0.029577     395

# %%
simulation_results_df['Clicks'] = simulation_results_df.apply(lambda x: calc_clicks(total_impressions=1000, pCTR=x['pCTR']), axis=1)
simulation_results_df['Total Spend'] = simulation_results_df.apply(lambda x: calc_total_spend(x['Clicks'], x['Price Paid']), axis=1)


simulation_results_df.groupby("Winner").agg({"Price Paid": "mean", "pCTR": "mean", "Minute": "count", "Clicks": "sum", "Total Spend": "sum"})

# add cost per click
simulation_results_df['Cost Per Click'] = simulation_results_df['Total Spend'] / simulation_results_df['Clicks']

simulation_results_df.groupby("Winner").agg({"Price Paid": "mean", "pCTR": "mean", "Minute": "count", "Clicks": "sum", "Total Spend": "sum", "Cost Per Click": "mean"})


# Cost per click are very similar for all campaigns
# Can introduce quality scores and impression charges?
# Out:
#                                                Price Paid      pCTR  Minute  \
# Winner
# Designing Data-Intensive Applications            0.404176  0.019651     253
# No Bid                                           0.000000  0.000000     600
# Practical Statistics for Data Scientists         0.381437  0.039863     193
# Time Series Analysis: Forecasting and Control    0.392213  0.029577     395
#
#                                                      Clicks  Total Spend  \
# Winner
# Designing Data-Intensive Applications           4971.689890  2000.289600
# No Bid                                             0.000000     0.000000
# Practical Statistics for Data Scientists        7693.619003  2935.939988
# Time Series Analysis: Forecasting and Control  11682.837859  4595.904614
#
#                                                Cost Per Click
# Winner
# Designing Data-Intensive Applications                0.404176
# No Bid                                                    NaN
# Practical Statistics for Data Scientists             0.381437
# Time Series Analysis: Forecasting and Control        0.393208

# %%
items_keywords_df
# Out:
#                                             Item          Keyword  pCTR   Bid  \
# 0  Time Series Analysis: Forecasting and Control  statistics book  0.03  0.50
# 1       Practical Statistics for Data Scientists  statistics book  0.04  0.48
# 2          Designing Data-Intensive Applications  statistics book  0.02  0.55
#
#    Budget
# 0    5000
# 1    3000
# 2    2000

# %%
# Out:
# 0

# %%
TODO:
    - Add Metrics and visualizations over minutes
    - Add a smoothness metric for pacing
    - Add PID

# %%
# for every item create a timeseries of 1440 minutes

timeseries = []

for item in items_keywords_df['Item']:
    for  minute in range(1440):
        budget = items_keywords_df[items_keywords_df['Item'] == item]['Budget'].values[0]
        timeseries_row = {
            'Minute': minute,
            'Item': item,
            'cumulative_expected_spend_linear': minute * budget / 1440,
        }
        timeseries.append(timeseries_row)
    
campaign_timeseries_df = pd.DataFrame(timeseries)

#plot
import matplotlib.pyplot as plt

# %%
from matplotlib import pyplot as plt

fig, axs = plt.subplots(3, figsize=(10, 18))  # Create 3 subplots

items = items_keywords_df['Item'].unique()  # Get unique items

for i in range(3):  # Loop over each subplot
    item = items[i]  # Get the item for this subplot
    axs[i].plot(campaign_timeseries_df[campaign_timeseries_df['Item'] == item]['Minute'], campaign_timeseries_df[campaign_timeseries_df['Item'] == item]['cumulative_expected_spend_linear'], label=item)
    axs[i].plot(simulation_results_df[simulation_results_df['Winner'] == item]['Minute'], 
                simulation_results_df[simulation_results_df['Winner'] == item]['Total Spend'].cumsum(), 
                label=f"{item} Actual")
    axs[i].legend()  # Add a legend to the subplot

plt.tight_layout()  # Adjust the layout to prevent overlap
plt.show()  # Display the plots

# %%
# save this

other
